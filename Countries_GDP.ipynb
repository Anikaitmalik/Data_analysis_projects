# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\anika\Downloads\GDP (1).csv")
# Out:
# C:\Users\anika\AppData\Local\Temp\ipykernel_16716\610777917.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(r"C:\Users\anika\Downloads\GDP (1).csv")

# %%
data.head(50)
# Out:
#                            Country          2000          2001          2002  \
# 0                            Aruba  33120.054180  32117.912320  30862.222690
# 1                      Afghanistan           NaN           NaN    839.485886
# 2                           Angola   3097.307292   3191.266323   3564.096026
# 3                          Albania   3861.334172   4301.352799   4661.371553
# 4                       Arab World   9415.632618   9584.108301   9581.797143
# 5             United Arab Emirates  82215.314470  80843.605370  79863.489730
# 6                        Argentina  11916.582610  11514.619110  10310.129120
# 7                          Armenia   2327.362521   2621.854364   3031.121882
# 8              Antigua and Barbuda  16526.987220  15804.121560  15994.176150
# 9                        Australia  26328.673680  27336.682690  28718.241080
# 10                         Austria  29380.066040  29715.222220  31178.693330
# ...

# %%
data.shape
# Out:
# (1048575, 22)

# %%
data.isnull().sum()
# Out:
# Country    1048315
# 2000       1048339
# 2001       1048338
# 2002       1048337
# 2003       1048337
# 2004       1048337
# 2005       1048337
# 2006       1048337
# 2007       1048336
# 2008       1048335
# 2009       1048334
# 2010       1048334
# 2011       1048332
# 2012       1048334
# 2013       1048334
# 2014       1048335
# 2015       1048337
# 2016       1048337
# 2017       1048337
# 2018       1048344
# Total            0
# Average          0
# dtype: int64

# %%
df = data.copy()

# %%
df.dropna(inplace = True)
df.drop_duplicates(inplace = True)

# %%
data.shape
# Out:
# (1048575, 22)

# %%
df.shape
# Out:
# (227, 22)

# %%
df.isnull().sum()
# Out:
# Country    0
# 2000       0
# 2001       0
# 2002       0
# 2003       0
# 2004       0
# 2005       0
# 2006       0
# 2007       0
# 2008       0
# 2009       0
# 2010       0
# 2011       0
# 2012       0
# 2013       0
# 2014       0
# 2015       0
# 2016       0
# 2017       0
# 2018       0
# Total      0
# Average    0
# dtype: int64

# %%
df.head(50)
# Out:
#                            Country          2000          2001          2002  \
# 2                           Angola   3097.307292   3191.266323   3564.096026
# 3                          Albania   3861.334172   4301.352799   4661.371553
# 4                       Arab World   9415.632618   9584.108301   9581.797143
# 5             United Arab Emirates  82215.314470  80843.605370  79863.489730
# 6                        Argentina  11916.582610  11514.619110  10310.129120
# 7                          Armenia   2327.362521   2621.854364   3031.121882
# 8              Antigua and Barbuda  16526.987220  15804.121560  15994.176150
# 9                        Australia  26328.673680  27336.682690  28718.241080
# 10                         Austria  29380.066040  29715.222220  31178.693330
# 11                      Azerbaijan   3663.445253   4082.682330   4504.976485
# 12                         Burundi    571.326312    582.467817    601.529756
# ...

# %%
df.describe()
# Out:
#                2000          2001          2002          2003           2004  \
# count    227.000000    227.000000    227.000000    227.000000     227.000000
# mean   10639.912918  11010.020067  11399.156062  11843.891708   12701.203219
# std    13251.626933  13485.454142  13869.202309  14326.655400   15327.939749
# min      455.815088    443.574712    450.450417    469.770410     498.979870
# 25%     2335.816834   2425.629386   2353.632784   2541.137727    2728.093217
# 50%     5815.873532   6110.458846   6327.810798   6528.675327    7093.957643
# 75%    12325.399695  13125.572820  13985.735035  14301.571445   14934.202510
# max    86169.394320  88138.422440  92091.276600  91451.608540  101329.478700
#
#                2005           2006           2007           2008  \
# count    227.000000     227.000000     227.000000     227.000000
# mean   13409.543447   14521.263330   15452.590444   16087.718180
# std    15789.744060   16937.443861   17597.467368   17868.568266
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 227 entries, 2 to 259
# Data columns (total 22 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  227 non-null    object
#  1   2000     227 non-null    float64
#  2   2001     227 non-null    float64
#  3   2002     227 non-null    float64
#  4   2003     227 non-null    float64
#  5   2004     227 non-null    float64
#  6   2005     227 non-null    float64
#  7   2006     227 non-null    float64
#  8   2007     227 non-null    float64
#  9   2008     227 non-null    float64
#  10  2009     227 non-null    float64
#  11  2010     227 non-null    float64
#  12  2011     227 non-null    float64
#  13  2012     227 non-null    float64
#  14  2013     227 non-null    float64
#  15  2014     227 non-null    float64
#  16  2015     227 non-null    float64
#  17  2016     227 non-null    float64
#  18  2017     227 non-null    float64
#  19  2018     227 non-null    float64
# ...

# %%
gdp_india=df.loc[df['Country']=='India']
gdp_us=df.loc[df['Country']=='United States']
gdp_uk=df.loc[df['Country']=='United Kingdom']
gdp_china=df.loc[df['Country']=='China']
gdp_pakistan=df.loc[df['Country']=='Pakistan']

nation_gdp=[gdp_india,gdp_china,gdp_pakistan,gdp_uk,gdp_us]
print(nation_gdp)
# Out:
# [    Country         2000         2001       2002         2003         2004  \
# 103   India  2156.689919  2270.718563  2354.2651  2544.112251  2774.420858
#
#             2005         2006         2007         2008  ...         2011  \
# 103  3039.128698  3331.592127  3628.001338  3757.289184  ...  4624.561404
#
#             2012         2013         2014         2015         2016  \
# 103  4909.584076  5252.272397  5682.731285  6133.887015  6634.844574
#
#             2017        2018        Total      Average
# 103  7168.992484  7762.88177  82412.50793  4337.500417
#
# [1 rows x 22 columns],    Country         2000         2001         2002         2003         2004  \
# 35   China  2936.287745  3227.419438  3553.923793  3958.471977  4449.561919
#
#            2005         2006         2007         2008  ...         2011  \
# 35  5081.049041  5867.796877  6847.069623  7615.029533  ...  10355.49571
#
#            2012         2013         2014         2015         2016  \
# ...

# %%
type(nation_gdp)
# Out:
# list

# %%
nation_gdp
# Out:
# [    Country         2000         2001       2002         2003         2004  \
#  103   India  2156.689919  2270.718563  2354.2651  2544.112251  2774.420858
#
#              2005         2006         2007         2008  ...         2011  \
#  103  3039.128698  3331.592127  3628.001338  3757.289184  ...  4624.561404
#
#              2012         2013         2014         2015         2016  \
#  103  4909.584076  5252.272397  5682.731285  6133.887015  6634.844574
#
#              2017        2018        Total      Average
#  103  7168.992484  7762.88177  82412.50793  4337.500417
#
#  [1 rows x 22 columns],
#     Country         2000         2001         2002         2003         2004  \
#  35   China  2936.287745  3227.419438  3553.923793  3958.471977  4449.561919
#
#             2005         2006         2007         2008  ...         2011  \
#  35  5081.049041  5867.796877  6847.069623  7615.029533  ...  10355.49571
#
# ...

# %%
gdp_india=df.loc[df['Country']=='India']
gdp_us=df.loc[df['Country']=='United States']
gdp_uk=df.loc[df['Country']=='United Kingdom']
gdp_china=df.loc[df['Country']=='China']
gdp_pakistan=df.loc[df['Country']=='Pakistan']


x_india=gdp_india.columns[1:20]
y_india=gdp_india.iloc[0,1:20]

x_pak = gdp_pakistan.columns[1:20]
y_pak = gdp_pakistan.iloc[0,1:20]

x_china = gdp_china.columns[1:20]
y_china = gdp_china.iloc[0,1:20]

# %%
x_india=gdp_india.columns[1:20]
print(x_india)
# Out:
# Index(['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018'],
#       dtype='object')

# %%
y_india=gdp_india.iloc[0,1:20]
print(y_india)
# Out:
# 2000    2156.689919
# 2001    2270.718563
# 2002      2354.2651
# 2003    2544.112251
# 2004    2774.420858
# 2005    3039.128698
# 2006    3331.592127
# 2007    3628.001338
# 2008    3757.289184
# 2009    4026.380833
# 2010     4360.15405
# 2011    4624.561404
# 2012    4909.584076
# 2013    5252.272397
# 2014    5682.731285
# 2015    6133.887015
# 2016    6634.844574
# 2017    7168.992484
# 2018     7762.88177
# Name: 103, dtype: object

# %%
gdp_india=df.loc[df['Country']=='India']
gdp_us=df.loc[df['Country']=='United States']
gdp_uk=df.loc[df['Country']=='United Kingdom']
gdp_china=df.loc[df['Country']=='China']
gdp_pakistan=df.loc[df['Country']=='Pakistan']


x_india=gdp_india.columns[1:20]
y_india=gdp_india.iloc[0,1:20]

x_pak = gdp_pakistan.columns[1:20]
y_pak = gdp_pakistan.iloc[0,1:20]

x_china = gdp_china.columns[1:20]
y_china = gdp_china.iloc[0,1:20]

fig=plt.figure()
fig.set_figwidth(30)
fig.set_figheight(30)

plt.plot(x_india,y_india,marker='o',linestyle='dashed',c='orange',mec='black',label='India',lw=5,ms=15)
plt.plot(x_pak,y_pak,marker='o',linestyle='dashed',c='green',mec='black',label='Pakistan',lw=5,ms=15)
plt.plot(x_china,y_china,marker='o',linestyle='dashed',c='red',mec='orange',label='China',lw=5,ms=15)

plt.title('GDP comparison  for India, China and Pakistan (2000-2018)',size=70,c='Blue',pad=110)
plt.xlabel('Year',size=80,labelpad=50)
plt.ylabel('GDP in Billion USD',size=80,labelpad=50)

plt.xticks(fontsize=30,rotation=70)
plt.yticks(fontsize=30)

plt.legend(bbox_to_anchor=(1,1),fontsize=50,facecolor='c',framealpha=0.2,fancybox=True)

plt.ylim((1000,20000))
plt.grid(axis='both',ls='dotted',lw=4)

# %%
nation_gdp
# Out:
# [    Country         2000         2001       2002         2003         2004  \
#  103   India  2156.689919  2270.718563  2354.2651  2544.112251  2774.420858
#
#              2005         2006         2007         2008  ...         2011  \
#  103  3039.128698  3331.592127  3628.001338  3757.289184  ...  4624.561404
#
#              2012         2013         2014         2015         2016  \
#  103  4909.584076  5252.272397  5682.731285  6133.887015  6634.844574
#
#              2017        2018        Total      Average
#  103  7168.992484  7762.88177  82412.50793  4337.500417
#
#  [1 rows x 22 columns],
#     Country         2000         2001         2002         2003         2004  \
#  35   China  2936.287745  3227.419438  3553.923793  3958.471977  4449.561919
#
#             2005         2006         2007         2008  ...         2011  \
#  35  5081.049041  5867.796877  6847.069623  7615.029533  ...  10355.49571
#
# ...

# %%
x_india=gdp_india.columns[1:20]
y_india=gdp_india.iloc[0,1:20]

x_pak = gdp_pakistan.columns[1:20]
y_pak = gdp_pakistan.iloc[0,1:20]

x_china = gdp_china.columns[1:20]
y_china = gdp_china.iloc[0,1:20]

fig=plt.figure()
fig.set_figwidth(30)
fig.set_figheight(30)

plt.bar(x_india,y_india,label='India',lw=5,color='orange',alpha=0.9)
plt.bar(x_pak,y_pak,label='Pakistan',lw=5,color='red',alpha=0.3)
plt.bar(x_china,y_china,label='China',lw=5,color='blue',alpha=0.1)

plt.title('GDP comparison for South Asian Major Countires',size=70,c='red',fontweight='bold',pad=100)
plt.xlabel('Year',size=50,labelpad=50)
plt.ylabel('GDP in Billion USD',size=50,labelpad=50)

plt.xticks(fontsize=30,rotation=70)
plt.yticks(fontsize=30)
plt.legend(bbox_to_anchor=(1,1),fontsize=50,facecolor='grey',framealpha=0.2)
plt.ylim((1000,20000))
plt.grid(axis='both',ls='dotted',lw=4)

# %%
ind_gdp18=gdp_india.iloc[0].at['2018']
us_gdp18=gdp_us.iloc[0].at['2018']
uk_gdp18=gdp_uk.iloc[0].at['2018']
chi_gdp18=gdp_china.iloc[0].at['2018']
pak_gdp18=gdp_pakistan.iloc[0].at['2018']

x=['US','UK','India','China','Pakistan']
y=[us_gdp18,uk_gdp18,ind_gdp18,chi_gdp18,pak_gdp18]
color=['grey','blue','orange','red','green']

fig=plt.figure()
fig.set_figwidth(10)
fig.set_figheight(10)

plt.bar(x,y,color=color)
plt.grid(axis='y',ls='dashed',lw=2)

plt.title('GDP comparison for 2018',color='brown',size=30,fontweight='bold')
plt.xlabel('Countries',size=25,color='purple')
plt.ylabel('GDP in Billion USD',size=25,color='purple')
plt.xticks(x,fontsize=20)
plt.ylim((500,65000))
# Out:
# (500.0, 65000.0)

# %%
india_gdp18=gdp_india.iloc[0].at['2018']
us_gdp18=gdp_us.iloc[0].at['2018']
uk_gdp18=gdp_uk.iloc[0].at['2018']
china_gdp18=gdp_china.iloc[0].at['2018']
pakistan_gdp18=gdp_pakistan.iloc[0].at['2018']


india_gdp2000=gdp_india.iloc[0].at['2000']
us_gdp2000=gdp_us.iloc[0].at['2000']
uk_gdp2000=gdp_uk.iloc[0].at['2000']
china_gdp2000=gdp_china.iloc[0].at['2000']
pakistan_gdp2000=gdp_pakistan.iloc[0].at['2000']

india_growth = round(((india_gdp18 - india_gdp2000)/100),2)
pakistan_growth = round(((pakistan_gdp18 - pakistan_gdp2000)/100),2)
uk_growth = round(((uk_gdp18 - uk_gdp2000)/100),2)
us_growth = round(((us_gdp18 - us_gdp2000)/100),2)
china_growth =round(((china_gdp18 - china_gdp2000)/100),2)


table  = { "Countries " : ["US" , "UK" , "INDIA" , "CHINA" , "PAKISTAN"] ,
         "GDP_GROWTH" : [us_growth,uk_growth,india_growth,china_growth,pakistan_growth]}

# %%
gpd_100 = pd.DataFrame(table)

# %%
gpd_100
# Out:
#   Countries   GDP_GROWTH
# 0         US      264.60
# 1         UK      195.66
# 2      INDIA       56.06
# 3      CHINA      153.00
# 4   PAKISTAN       28.61

# %%
india_gdp18=gdp_india.iloc[0].at['2018']
us_gdp18=gdp_us.iloc[0].at['2018']
uk_gdp18=gdp_uk.iloc[0].at['2018']
china_gdp18=gdp_china.iloc[0].at['2018']
pakistan_gdp18=gdp_pakistan.iloc[0].at['2018']


india_gdp2000=gdp_india.iloc[0].at['2000']
us_gdp2000=gdp_us.iloc[0].at['2000']
uk_gdp2000=gdp_uk.iloc[0].at['2000']
china_gdp2000=gdp_china.iloc[0].at['2000']
pakistan_gdp2000=gdp_pakistan.iloc[0].at['2000']

india_growth = round(((india_gdp18 - india_gdp2000)/100),2)
pakistan_growth = round(((pakistan_gdp18 - pakistan_gdp2000)/100),2)
uk_growth = round(((uk_gdp18 - uk_gdp2000)/100),2)
us_growth = round(((us_gdp18 - us_gdp2000)/100),2)
china_growth =round(((china_gdp18 - china_gdp2000)/100),2)

Countries=  ["US" , "UK" , "INDIA" , "CHINA" , "PAKISTAN"]
GDP_GROWTH =[us_growth,uk_growth,india_growth,china_growth,pakistan_growth]
colours = ["red" ,"green" , "yellow" , "blue" , "orange"]
plt.bar(Countries , GDP_GROWTH , color = colours )
plt.grid(axis='y',ls='dotted')

plt.title('Percentage GDP growth 2000-2018',fontsize=25,pad=50,color='black')
plt.xlabel('Countries',fontsize=25,color='grey',labelpad=20)
plt.ylabel('Percentage growth',fontsize=25,color='grey',labelpad=20)
plt.show()

# %%
top20_gdp_countries = df.loc[df["Average"] >

# %%
df.columns
# Out:
# Index(['Country', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', 'Total', 'Average'],
#       dtype='object')
